# %% [markdown]
# # Selenium with Python

# %% [markdown]
# ## Required Library

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /Users/inflaton/miniconda3/lib/python3.10/site-packages (4.8.3)
# Requirement already satisfied: urllib3[socks]~=1.26 in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from selenium) (1.26.14)
# Requirement already satisfied: certifi>=2021.10.8 in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from selenium) (2022.12.7)
# Requirement already satisfied: trio~=0.17 in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from selenium) (0.10.2)
# Requirement already satisfied: outcome in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.1.1)
# Requirement already satisfied: idna in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: async-generator>=1.9 in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (22.2.0)
# Requirement already satisfied: sortedcontainers in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: wsproto>=0.14 in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/inflaton/miniconda3/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# ## Testing with Chrome Automation

# %% [markdown]
# Refer to https://www.browserstack.com/guide/python-selenium-to-run-web-automation-test
#
# 1. First import the WebDriver and Keys classes from Selenium.

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# 2. Next, create an instance of Chrome with the path of the driver that you downloaded through the websites of the respective browser. In this example, we assume that the driver is in the same directory as the Python script that you will execute.

# %%
driver = webdriver.Chrome()

# %% [markdown]
# 3. Set up

# %%
driver.get("http://localhost:3000/")

# %% [markdown]
# 4. Define functions for test case

# %%
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.by import By

def query(question):
    wait = WebDriverWait(driver, 160)
    user_input = wait.until(EC.element_to_be_clickable((By.ID, 'userInput')))

    print("asking question: " + question)

    user_input = driver.find_element("name", "userInput")
    user_input.clear()
    user_input.send_keys(question)
    user_input.send_keys(Keys.RETURN)

def run(vectorStore):
    print("run test case with vector store: " + vectorStore)
    driver.get("http://localhost:3000/")

    query("What is Mastercard Priceless?")
    query("Dining in New York")
    query("Russian Tea Room?")
    query("请推荐一下纽约的娱乐")

    wait = WebDriverWait(driver, 160)
    user_input = wait.until(EC.element_to_be_clickable((By.ID, 'userInput')))

# %% [markdown]
# 5. Run test cases

# %%
# %%time

run("pinecone")
# Out:
# run test case with vector store: pinecone
# asking question: What is Mastercard Priceless?
# asking question: Dining in New York
# asking question: Russian Tea Room?
# asking question: 请推荐一下纽约的娱乐
# CPU times: user 246 ms, sys: 36.7 ms, total: 283 ms
# Wall time: 1min 26s

# %%
# %%time

run("hnswlib")
# Out:
# run test case with vector store: hnswlib
# asking question: What is Mastercard Priceless?
# asking question: Dining in New York
# asking question: Russian Tea Room?
# asking question: 请推荐一下纽约的娱乐
# CPU times: user 239 ms, sys: 44.4 ms, total: 284 ms
# Wall time: 1min 22s

# %%
# %%time

run("chroma")
# Out:
# run test case with vector store: chroma
# asking question: What is Mastercard Priceless?
# asking question: Dining in New York
# asking question: Russian Tea Room?
# asking question: 请推荐一下纽约的娱乐
# CPU times: user 272 ms, sys: 50.7 ms, total: 323 ms
# Wall time: 1min 34s

# %%
# %%time

run("milvus")
# Out:
# run test case with vector store: milvus
# asking question: What is Mastercard Priceless?
# asking question: Dining in New York
# asking question: Russian Tea Room?
# asking question: 请推荐一下纽约的娱乐
# CPU times: user 221 ms, sys: 34 ms, total: 255 ms
# Wall time: 1min 13s

# %% [markdown]
# 5. Tear down

# %%
driver.close()
